# %% [markdown]
# [단어 통합]
# - 바이그램, 트라이그램 방법으로 각각 진행 예정
#
# [불용어 제거]
# - 불용어를 추가한 다음, 추가한 불용어를 제거할 예정

# %% [markdown]
# # 단어 통합
# ## 바이그램

# %%
import pandas as pd
import numpy as np
from nltk import bigrams, word_tokenize
from nltk.util import ngrams
import re

import konlpy
from konlpy.tag import Okt

# 경고제어
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('everytime_review_data.csv')

# %%
df.head()
# Out:
#              강의명  학점 강좌유형 패논패여부 이수학년 전공여부  학과  교수명  \
# 0  기업가정신과창업(KCU)   3   이론     x  전학년   교양  교양  김한수
# 1  기업가정신과창업(KCU)   3   이론     x  전학년   교양  교양  김한수
# 2  기업가정신과창업(KCU)   3   이론     x  전학년   교양  교양  김한수
# 3  기업가정신과창업(KCU)   3   이론     x  전학년   교양  교양  김한수
# 4  기업가정신과창업(KCU)   3   이론     x  전학년   교양  교양  김한수
#
#                                                   리뷰         작성시점  평가별점수  공감수  \
# 0                       첫 kcu 강의 퀄리티 떨어지지만 에이쁠 받기 쉬움  22년 2학기 수강자      4    0
# 1  그저그래요. 다른건 다 낫배드했는데 기말고사로는 서술형 1문제가 나왔어요. 비중도 ...  22년 2학기 수강자      4    0
# 2  기창 강의평 피드백 없고 강의안도 없지만 그래도 할만한 꿀강... 퀴즈 2번 + 기...  22년 2학기 수강자      4    0
# 3  과제 하나도 없고 출석 퀴즈2번 기말1번만 하면됨 퀴즈는 인터넷 서치해야하고 강의록...  22년 2학기 수강자      3    0
# 4  KCU 5과목 정도 수강했는데 그중에 제일 별로.. 퀴즈2번 기말고사1번 수업에서 ...  22년 2학기 수강자      3    0
#
#    리뷰길이                                             리뷰_형태소
# 0    28  ['첫', 'kcu', '강의', '퀄리티', '떨어지지만', '에', '이쁠', ...
# 1   131  ['그저', '그래요', '.', '다른건', '다', '낫', '배드', '했는데...
# 2   232  ['기', '창', '강의', '평', '피드백', '없고', '강의', '안도',...
# 3    96  ['과제', '하나', '도', '없고', '출석', '퀴즈', '2', '번', ...
# 4   167  ['KCU', '5', '과목', '정도', '수강', '했는데', '그', '중'...

# %%
reviews = df[['리뷰']]
reviews.head()
# Out:
#                                                   리뷰
# 0                       첫 kcu 강의 퀄리티 떨어지지만 에이쁠 받기 쉬움
# 1  그저그래요. 다른건 다 낫배드했는데 기말고사로는 서술형 1문제가 나왔어요. 비중도 ...
# 2  기창 강의평 피드백 없고 강의안도 없지만 그래도 할만한 꿀강... 퀴즈 2번 + 기...
# 3  과제 하나도 없고 출석 퀴즈2번 기말1번만 하면됨 퀴즈는 인터넷 서치해야하고 강의록...
# 4  KCU 5과목 정도 수강했는데 그중에 제일 별로.. 퀴즈2번 기말고사1번 수업에서 ...

# %% [markdown]
# - 정규표현식으로 한글 영어 제외하고 제거

# %%
# 정규표현식으로 한글, 영어, 공백 제외하고 특수문자 제거
reviews['리뷰'] = [re.sub(r"[^ㄱ-ㅣ가-힣a-zA-Z\s]", '', s) for s in reviews['리뷰']]
# Out:
# /var/folders/gx/q7vn3yv17rvb0vy6chbbbztw0000gn/T/ipykernel_3232/1162274324.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['리뷰'] = [re.sub(r"[^ㄱ-ㅣ가-힣a-zA-Z\s]", '', s) for s in reviews['리뷰']]

# %%
reviews['바이그램'] = 0
for i in range(len(reviews['리뷰'])):
    bigs = []
    bigram_plus = []
    a = reviews['리뷰'][i]
    tokens = word_tokenize(a)
    bigram = bigrams(tokens)
    for j in bigram:
        bigs.append(j)

    for k in range(len(bigs)):
        big = bigs[k][0] + " " + bigs[k][1]
        bigram_plus.append(big)
    s = ", ".join(bigram_plus)
    reviews['바이그램'][i] = s
# Out:
# /var/folders/gx/q7vn3yv17rvb0vy6chbbbztw0000gn/T/ipykernel_3232/3155431774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['바이그램'] = 0
# /var/folders/gx/q7vn3yv17rvb0vy6chbbbztw0000gn/T/ipykernel_3232/3155431774.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['바이그램'][i] = s

# %%
reviews
# Out:
#                                                        리뷰  \
# 0                            첫 kcu 강의 퀄리티 떨어지지만 에이쁠 받기 쉬움
# 1       그저그래요 다른건 다 낫배드했는데 기말고사로는 서술형 문제가 나왔어요 비중도 제일 ...
# 2       기창 강의평 피드백 없고 강의안도 없지만 그래도 할만한 꿀강 퀴즈 번  기말 시험 ...
# 3       과제 하나도 없고 출석 퀴즈번 기말번만 하면됨 퀴즈는 인터넷 서치해야하고 강의록도 ...
# 4       KCU 과목 정도 수강했는데 그중에 제일 별로 퀴즈번 기말고사번 수업에서 안 배운 ...
# ...                                                   ...
# 121583  최고의 교수님 두 학기 연속으로 들었는데 학점 정말 잘 주신다 항상 학생들을 먼저 ...
# 121584  학점 절대평가인 것 같고 비대면이라 좋았음 에릭 교수님 이번 학기가 마지막이라 강의...
# 121585                            에릭교수님 점수 후하게 잘 주시고 좋습니다
# 121586  영회는 에릭 교수님이 짱이다 진심으로 영어를 못해도 잘 이끌어주시고 점점 영어회화에...
# 121587  다른 교수님 영어회화 수업을 들어보지는 않았지만 에릭교수님을 선택한건 절대 후회하지 않음
#
#                                                      바이그램
# 0       첫 kcu, kcu 강의, 강의 퀄리티, 퀄리티 떨어지지만, 떨어지지만 에이쁠, 에...
# 1       그저그래요 다른건, 다른건 다, 다 낫배드했는데, 낫배드했는데 기말고사로는, 기말고...
# 2       기창 강의평, 강의평 피드백, 피드백 없고, 없고 강의안도, 강의안도 없지만, 없지...
# 3       과제 하나도, 하나도 없고, 없고 출석, 출석 퀴즈번, 퀴즈번 기말번만, 기말번만 ...
# 4       KCU 과목, 과목 정도, 정도 수강했는데, 수강했는데 그중에, 그중에 제일, 제일...
# ...                                                   ...
# 121583  최고의 교수님, 교수님 두, 두 학기, 학기 연속으로, 연속으로 들었는데, 들었는데...
# 121584  학점 절대평가인, 절대평가인 것, 것 같고, 같고 비대면이라, 비대면이라 좋았음, ...
# 121585           에릭교수님 점수, 점수 후하게, 후하게 잘, 잘 주시고, 주시고 좋습니다
# 121586  영회는 에릭, 에릭 교수님이, 교수님이 짱이다, 짱이다 진심으로, 진심으로 영어를,...
# 121587  다른 교수님, 교수님 영어회화, 영어회화 수업을, 수업을 들어보지는, 들어보지는 않...
#
# [121588 rows x 2 columns]

# %% [markdown]
# ### 트라이그램

# %%
a = reviews['리뷰'][0]
tokens = word_tokenize(a)
trigram = ngrams(tokens,3)

# %%
for t in trigram:
    print(t)
# Out:
# ('첫', 'kcu', '강의')
# ('kcu', '강의', '퀄리티')
# ('강의', '퀄리티', '떨어지지만')
# ('퀄리티', '떨어지지만', '에이쁠')
# ('떨어지지만', '에이쁠', '받기')
# ('에이쁠', '받기', '쉬움')

# %%
reviews['트라이그램'] = 0
for i in range(len(reviews['리뷰'])):
    tries = []
    trigram_plus = []
    a = reviews['리뷰'][i]
    tokens = word_tokenize(a)
    trigram = ngrams(tokens,3)
    for j in trigram:
        tries.append(j)

    for k in range(len(tries)):
        tri = tries[k][0] + " " + tries[k][1] + " " + tries[k][2]
        trigram_plus.append(tri)
    s = ", ".join(trigram_plus)
    reviews['트라이그램'][i] = s
# Out:
# /var/folders/gx/q7vn3yv17rvb0vy6chbbbztw0000gn/T/ipykernel_3232/1689607513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['트라이그램'] = 0
# /var/folders/gx/q7vn3yv17rvb0vy6chbbbztw0000gn/T/ipykernel_3232/1689607513.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['트라이그램'][i] = s

# %%
reviews
# Out:
#                                                        리뷰  \
# 0                            첫 kcu 강의 퀄리티 떨어지지만 에이쁠 받기 쉬움
# 1       그저그래요 다른건 다 낫배드했는데 기말고사로는 서술형 문제가 나왔어요 비중도 제일 ...
# 2       기창 강의평 피드백 없고 강의안도 없지만 그래도 할만한 꿀강 퀴즈 번  기말 시험 ...
# 3       과제 하나도 없고 출석 퀴즈번 기말번만 하면됨 퀴즈는 인터넷 서치해야하고 강의록도 ...
# 4       KCU 과목 정도 수강했는데 그중에 제일 별로 퀴즈번 기말고사번 수업에서 안 배운 ...
# ...                                                   ...
# 121583  최고의 교수님 두 학기 연속으로 들었는데 학점 정말 잘 주신다 항상 학생들을 먼저 ...
# 121584  학점 절대평가인 것 같고 비대면이라 좋았음 에릭 교수님 이번 학기가 마지막이라 강의...
# 121585                            에릭교수님 점수 후하게 잘 주시고 좋습니다
# 121586  영회는 에릭 교수님이 짱이다 진심으로 영어를 못해도 잘 이끌어주시고 점점 영어회화에...
# 121587  다른 교수님 영어회화 수업을 들어보지는 않았지만 에릭교수님을 선택한건 절대 후회하지 않음
#
#                                                      바이그램  \
# 0       첫 kcu, kcu 강의, 강의 퀄리티, 퀄리티 떨어지지만, 떨어지지만 에이쁠, 에...
# 1       그저그래요 다른건, 다른건 다, 다 낫배드했는데, 낫배드했는데 기말고사로는, 기말고...
# 2       기창 강의평, 강의평 피드백, 피드백 없고, 없고 강의안도, 강의안도 없지만, 없지...
# 3       과제 하나도, 하나도 없고, 없고 출석, 출석 퀴즈번, 퀴즈번 기말번만, 기말번만 ...
# 4       KCU 과목, 과목 정도, 정도 수강했는데, 수강했는데 그중에, 그중에 제일, 제일...
# ...                                                   ...
# 121583  최고의 교수님, 교수님 두, 두 학기, 학기 연속으로, 연속으로 들었는데, 들었는데...
# 121584  학점 절대평가인, 절대평가인 것, 것 같고, 같고 비대면이라, 비대면이라 좋았음, ...
# 121585           에릭교수님 점수, 점수 후하게, 후하게 잘, 잘 주시고, 주시고 좋습니다
# 121586  영회는 에릭, 에릭 교수님이, 교수님이 짱이다, 짱이다 진심으로, 진심으로 영어를,...
# 121587  다른 교수님, 교수님 영어회화, 영어회화 수업을, 수업을 들어보지는, 들어보지는 않...
#
#                                                     트라이그램
# 0       첫 kcu 강의, kcu 강의 퀄리티, 강의 퀄리티 떨어지지만, 퀄리티 떨어지지만 ...
# 1       그저그래요 다른건 다, 다른건 다 낫배드했는데, 다 낫배드했는데 기말고사로는, 낫배...
# 2       기창 강의평 피드백, 강의평 피드백 없고, 피드백 없고 강의안도, 없고 강의안도 없...
# 3       과제 하나도 없고, 하나도 없고 출석, 없고 출석 퀴즈번, 출석 퀴즈번 기말번만, ...
# 4       KCU 과목 정도, 과목 정도 수강했는데, 정도 수강했는데 그중에, 수강했는데 그중...
# ...                                                   ...
# 121583  최고의 교수님 두, 교수님 두 학기, 두 학기 연속으로, 학기 연속으로 들었는데, ...
# 121584  학점 절대평가인 것, 절대평가인 것 같고, 것 같고 비대면이라, 같고 비대면이라 좋...
# 121585      에릭교수님 점수 후하게, 점수 후하게 잘, 후하게 잘 주시고, 잘 주시고 좋습니다
# 121586  영회는 에릭 교수님이, 에릭 교수님이 짱이다, 교수님이 짱이다 진심으로, 짱이다 진...
# 121587  다른 교수님 영어회화, 교수님 영어회화 수업을, 영어회화 수업을 들어보지는, 수업을...
#
# [121588 rows x 3 columns]

# %%
df['바이그램'] = reviews['바이그램']
df['트라이그램'] = reviews['트라이그램']
df.head()
# Out:
#              강의명  학점 강좌유형 패논패여부 이수학년 전공여부  학과  교수명  \
# 0  기업가정신과창업(KCU)   3   이론     x  전학년   교양  교양  김한수
# 1  기업가정신과창업(KCU)   3   이론     x  전학년   교양  교양  김한수
# 2  기업가정신과창업(KCU)   3   이론     x  전학년   교양  교양  김한수
# 3  기업가정신과창업(KCU)   3   이론     x  전학년   교양  교양  김한수
# 4  기업가정신과창업(KCU)   3   이론     x  전학년   교양  교양  김한수
#
#                                                   리뷰         작성시점  평가별점수  공감수  \
# 0                       첫 kcu 강의 퀄리티 떨어지지만 에이쁠 받기 쉬움  22년 2학기 수강자      4    0
# 1  그저그래요. 다른건 다 낫배드했는데 기말고사로는 서술형 1문제가 나왔어요. 비중도 ...  22년 2학기 수강자      4    0
# 2  기창 강의평 피드백 없고 강의안도 없지만 그래도 할만한 꿀강... 퀴즈 2번 + 기...  22년 2학기 수강자      4    0
# 3  과제 하나도 없고 출석 퀴즈2번 기말1번만 하면됨 퀴즈는 인터넷 서치해야하고 강의록...  22년 2학기 수강자      3    0
# 4  KCU 5과목 정도 수강했는데 그중에 제일 별로.. 퀴즈2번 기말고사1번 수업에서 ...  22년 2학기 수강자      3    0
#
#    리뷰길이                                             리뷰_형태소  \
# 0    28  ['첫', 'kcu', '강의', '퀄리티', '떨어지지만', '에', '이쁠', ...
# 1   131  ['그저', '그래요', '.', '다른건', '다', '낫', '배드', '했는데...
# 2   232  ['기', '창', '강의', '평', '피드백', '없고', '강의', '안도',...
# 3    96  ['과제', '하나', '도', '없고', '출석', '퀴즈', '2', '번', ...
# 4   167  ['KCU', '5', '과목', '정도', '수강', '했는데', '그', '중'...
#
#                                                 바이그램  \
# 0  첫 kcu, kcu 강의, 강의 퀄리티, 퀄리티 떨어지지만, 떨어지지만 에이쁠, 에...
# 1  그저그래요 다른건, 다른건 다, 다 낫배드했는데, 낫배드했는데 기말고사로는, 기말고...
# 2  기창 강의평, 강의평 피드백, 피드백 없고, 없고 강의안도, 강의안도 없지만, 없지...
# 3  과제 하나도, 하나도 없고, 없고 출석, 출석 퀴즈번, 퀴즈번 기말번만, 기말번만 ...
# 4  KCU 과목, 과목 정도, 정도 수강했는데, 수강했는데 그중에, 그중에 제일, 제일...
#
#                                                트라이그램
# 0  첫 kcu 강의, kcu 강의 퀄리티, 강의 퀄리티 떨어지지만, 퀄리티 떨어지지만 ...
# 1  그저그래요 다른건 다, 다른건 다 낫배드했는데, 다 낫배드했는데 기말고사로는, 낫배...
# 2  기창 강의평 피드백, 강의평 피드백 없고, 피드백 없고 강의안도, 없고 강의안도 없...
# 3  과제 하나도 없고, 하나도 없고 출석, 없고 출석 퀴즈번, 출석 퀴즈번 기말번만, ...
# 4  KCU 과목 정도, 과목 정도 수강했는데, 정도 수강했는데 그중에, 수강했는데 그중...

# %% [markdown]
# ## 불용어 제거
